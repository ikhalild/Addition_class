# %% [markdown]
# # 📦 **Séance 1 — Manipulation avec Pandas & Numpy (Amazon Dataset)**
# **Objectif :** Charger, inspecter, manipuler et explorer des données tabulaires réelles avec `pandas`.

# %%
# Importer les bibliotheques dont aura besoin
import pandas as pd
import numpy as np

# %%
# Télécharger le fichier CSV directement depuis GitHub
# !wget https://raw.githubusercontent.com/bidoscar/AFRICITIZEN-ACDS-Coding/main/Seance_1/Datasets/amazon.csv
# Out:
# --2025-07-12 20:56:36--  https://raw.githubusercontent.com/bidoscar/AFRICITIZEN-ACDS-Coding/main/Seance_1/Datasets/amazon.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4744481 (4.5M) [text/plain]
# Saving to: ‘amazon.csv’
#
# amazon.csv          100%[===================>]   4.52M  12.2MB/s    in 0.4s
#
# 2025-07-12 20:56:37 (12.2 MB/s) - ‘amazon.csv’ saved [4744481/4744481]

# %% [markdown]
# ## **Description du jeu de données Amazon Dataset**

# %% [markdown]
# | Colonne             | Description en français                                                   |
# |---------------------|---------------------------------------------------------------------------|
# | `product_id`        | Identifiant unique du produit                                             |
# | `product_name`      | Nom du produit                                                            |
# | `category`          | Catégorie ou arborescence du produit sur Amazon                          |
# | `discounted_price`  | Prix remisé du produit (après réduction)                                 |
# | `actual_price`      | Prix initial (sans réduction)                                            |
# | `discount_percentage` | Pourcentage de réduction appliqué                                     |
# | `rating`            | Note moyenne donnée par les utilisateurs (sur 5)                         |
# | `rating_count`      | Nombre d’utilisateurs ayant évalué le produit                            |
# | `about_product`     | Description ou caractéristiques principales du produit                   |
# | `user_id`           | Identifiant(s) des utilisateur(s) ayant laissé un avis                   |
# | `user_name`         | Nom(s) des utilisateur(s) ayant laissé un avis                           |
# | `review_id`         | Identifiant unique de l’avis utilisateur                                 |
# | `review_title`      | Titre court ou résumé de l’avis                                          |
# | `review_content`    | Contenu détaillé de l’avis                                                |
# | `img_link`          | Lien vers l’image du produit                                              |
# | `product_link`      | Lien vers la fiche produit officielle sur Amazon                         |

# %%
# Charger notre jeux de donnees
df = pd.read_csv("amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ## 🔍 Exploration des données
# - Dimensions du dataset
# - Types de données
# - Valeurs manquantes

# %%
df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
# ▶️ Indexation : accès direct à une colonne
print("Accès à la colonne 'discount_percentage' :")
df["discount_percentage"]
# Out:
# Accès à la colonne 'discount_percentage' :
# 0       64%
# 1       43%
# 2       90%
# 3       53%
# 4       61%
#        ...
# 1460    59%
# 1461    25%
# 1462    28%
# 1463    26%
# 1464    22%
# Name: discount_percentage, Length: 1465, dtype: object

# %%
# ▶️ Slicing : découpage de lignes (par position)
print("\nAfficher les 3 premiers produits :")
df[0:3]
# Out:
# Afficher les 3 premiers produits :
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
# ▶️ Slicing avec iloc (par position)
print("\nProduit à la 2e ligne (iloc) :")
df.iloc[1]
# Out:
# Produit à la 2e ligne (iloc) :
# product_id                                                    B098NS6PVG
# product_name           Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# category               Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                    ₹199
# actual_price                                                        ₹349
# discount_percentage                                                  43%
# rating                                                               4.0
# rating_count                                                      43,994
# about_product          Compatible with all Type C enabled devices, be...
# user_id                AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# user_name              ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# review_id              RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# ...

# %%
# Afficher le contenu qui se trouve à l'intersection de la deuxième ligne et la première colonne (product_id)
df.iloc[(1,0)] # 1 (pour dire 2ème ligne en comptant a partir de 0) et 0 (pour dire 1ère colonne)
# Out:
# 'B098NS6PVG'

# %%
# ▶️ Slicing avec loc (par nom)
df.loc[df["product_id"] == "B098NS6PVG"] # affiche les lignes dont le product_id est B098NS6PVG
# Out:
#      product_id                                       product_name  \
# 1    B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 377  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 622  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                               category discounted_price  \
# 1    Computers&Accessories|Accessories&Peripherals|...             ₹199
# 377  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 622  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#     actual_price discount_percentage rating rating_count  \
# 1           ₹349                 43%    4.0       43,994
# 377         ₹349                 43%    4.0       43,993
# 622         ₹349                 43%    4.0       43,994
#
#                                          about_product  \
# 1    Compatible with all Type C enabled devices, be...
# 377  Compatible with all Type C enabled devices, be...
# ...

# %%
# ▶️ Slicing avec loc (par nom)
df.loc[df["product_id"] == "B098NS6PVG"]["product_name"] # affiche les lignes dont le product_id est B098NS6PVG et uniquement la colonne product_name
# Out:
# 1      Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 377    Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 622    Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# Name: product_name, dtype: object

# %% [markdown]
# ## 🎯 **Nettoyage des colonnes numériques**
# Nous allons convertir les colonnes de prix, rating et nombre d'avis en float. Nous allons aussi enlever le signe % de la colonne discount_percentage

# %%
# Créons d'abord une copie de notre jeu de données
df1 = df.copy()

# %%
# Dressons le tableau des effectifs de la colonne rating pour voir pourquoi c'est de type object
df1['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 3.0      3
# 4.8      3
# 5.0      3
# 2.8      2
# 3.2      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
# On a remarqué la présence de | dans la colonne rating
# Essayons de le remplacer par une value manquant (on peut aussi décider de le remplacer avec la médiane ou la moyenne)
df1['rating'] = df1['rating'].replace('|', np.nan)

# %%
# Enlevons le symbol de devise et le délimitateur de millier
df1['discounted_price'] = df1['discounted_price'].str.replace("₹", "").str.replace(",", "").astype(float)
df1['actual_price'] = df1['actual_price'].str.replace("₹", "").str.replace(",", "").astype(float)
df1['rating'] = df1['rating'].str.replace(",", "").astype(float)
df1['rating_count'] = df1['rating_count'].str.replace(",", "").astype(float)

# %%
# Changeons le type de donnée et ramenons le pourcentage en proportion (entre 0 et 1) dans discount_Percentage
df1['discount_percentage'] = df1['discount_percentage'].str.replace('%','').astype('float64')
df1['discount_percentage'] = df1['discount_percentage'] / 100

# %%
# Affichons les colonne modifiées
df1[['discounted_price', 'actual_price', 'rating', 'rating_count', 'discount_percentage']].head()
# Out:
#    discounted_price  actual_price  rating  rating_count  discount_percentage
# 0             399.0        1099.0     4.2       24269.0                 0.64
# 1             199.0         349.0     4.0       43994.0                 0.43
# 2             199.0        1899.0     3.9        7928.0                 0.90
# 3             329.0         699.0     4.2       94363.0                 0.53
# 4             154.0         399.0     4.2       16905.0                 0.61

# %%
# Avant d'entamer les problèmes, faisons une nouvelle copie de notre jeu de données
df2 = df1.copy()

# %% [markdown]
# # **Problème 1**

# %% [markdown]
# **Quel est le vrai prix sans discount du produit le moins cher parmi les mieux notés ?**

# %%
# Que demande ce problème ?
# On cherche le vrai prix dans discount (c'est-à-dire la colonne actual_price) du produit le moins cher (colonne discounted price)
# parmi les mieux notés (colonne rating)

# Pour ce faire il faut :
# 1. Trouver la meilleure note
# 2. Filtrer les produits ayant cette note
# 3. Trouver le prix le plus bas parmi ceux-là
# 4. Garder uniquement les lignes qui ont ce prix
# 5. Afficher le résultat

# %%
# 1. Trouver la meilleure note
meilleur_note = df2['rating'].max()
meilleur_note
# Out:
# 5.0

# %%
# 2. Filtrer les produits ayant cette note
high_rating = df2[df2['rating'] == meilleur_note]
high_rating
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#                                               category  discounted_price  \
# 174  Computers&Accessories|Accessories&Peripherals|...             399.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
# 775  Computers&Accessories|Accessories&Peripherals|...             499.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 174        1999.0                 0.80     5.0           5.0
# 324         999.0                 0.75     5.0           NaN
# 775        1000.0                 0.50     5.0          23.0
#
#                                          about_product  \
# 174  This sturdy and durable cable made of tpe and ...
# ...

# %%
# 3. Trouver le prix le plus bas parmi ceux-là
min_price = high_rating['discounted_price'].min()
min_price
# Out:
# 249.0

# %%
# 4. Garder uniquement les lignes qui ont ce prix
result = high_rating[high_rating['discounted_price'] == min_price]
result
# Out:
#      product_id                                       product_name  \
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 324         999.0                 0.75     5.0           NaN
#
#                                          about_product  \
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
#         review_title                                     review_content  \
# 324  Awesome Product  Quick delivery.Awesome ProductPacking was good...
#
#                                               img_link  \
# 324  https://m.media-amazon.com/images/I/31-q0xhaTA...
#
# ...

# %%
# 5. Afficher le résultat
result[['actual_price']]
# Out:
#      actual_price
# 324         999.0

# %% [markdown]
# # **Problème 2**

# %% [markdown]
# **Quel est le vrai prix sans discount du produit le mieux noté parmi les moins chers ?**

# %%
# Le raisonnement est le méme que dans le problème 1

# %%
# 1. Trouver le prix le plus bas globalement
min_price = df2['discounted_price'].min()

# %%
# 2. Filtrer les produits ayant ce prix
cheapest_products = df2[df2['discounted_price'] == min_price]

# %%
# 3. Parmi eux, trouver ceux ayant la meilleure note
max_rating = cheapest_products['rating'].max()

# %%
# 4. Sélectionner les produits avec ce rating maximal
result = cheapest_products[cheapest_products['rating'] == max_rating]

# %%
# 5. Afficher le vrai prix sans discount
result['actual_price']
# Out:
# 975    39.0
# Name: actual_price, dtype: float64

# %% [markdown]
# # **Problème 3**

# %% [markdown]
# **Comment calculer et afficher le prix final TTC (avec 18% de TVA sur le prix remisé)**

# %%
# On commence par créer une nouvelle colonne contant la TVA
df2['TVA'] = df2['discounted_price'] * 0.18

# Ensuite une nouvelle colonne pour le prix Tout Taxe Compris (qui est la somme entre la TVA et le prix après réduction)
df2['Prix_TTC'] = df2['discounted_price'] + df2['TVA']

# On affiche le 5 première ligne du résultat
df2[['discounted_price', 'TVA', 'Prix_TTC']].head()
# Out:
#    discounted_price    TVA  Prix_TTC
# 0             399.0  71.82    470.82
# 1             199.0  35.82    234.82
# 2             199.0  35.82    234.82
# 3             329.0  59.22    388.22
# 4             154.0  27.72    181.72

# %% [markdown]
# # 🧠 **Mini-projet Statistique**

# %% [markdown]
# **Quelle est la catégorie de produits dont le prix TTC moyen est le plus élevé ?**

# %%
# On calcule le prix TTC moyen
df2['Prix_TTC'].mean()
# Out:
# np.float64(3687.8668309897616)

# %%
# On regroupe les lignes par catégorie
df2.groupby('category')

# %%
# On calcule le prix TTC moyen pour chaque catégorie
df2.groupby('category')['Prix_TTC'].mean()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    2760.020000
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                    261.370000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                            765.820000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                         677.320000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                            883.820000
#                                                                                                                              ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         177.000000
# ...

# %%
# On trie les résultats du plus élevé au plus bas
df2.groupby('category')['Prix_TTC'].mean().sort_values(ascending=False)
# Out:
# category
# Home&Kitchen|Heating,Cooling&AirQuality|AirConditioners|Split-SystemAirConditioners                              50728.200000
# Computers&Accessories|Laptops|TraditionalLaptops                                                                 43951.460000
# Computers&Accessories|Tablets                                                                                    31858.820000
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                    29311.424762
# Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|RoboticVacuums             27670.410000
#                                                                                                                      ...
# Home&Kitchen|CraftMaterials|DrawingMaterials|DrawingMedia|Pencils|WoodenPencils                                    116.820000
# ...

# %%
# On affiche les 6 premières catégories
df2.groupby('category')['Prix_TTC'].mean().sort_values(ascending=False).head(6)
# Out:
# category
# Home&Kitchen|Heating,Cooling&AirQuality|AirConditioners|Split-SystemAirConditioners                     50728.200000
# Computers&Accessories|Laptops|TraditionalLaptops                                                        43951.460000
# Computers&Accessories|Tablets                                                                           31858.820000
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                           29311.424762
# Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|Vacuums|RoboticVacuums    27670.410000
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                    18590.240588
# Name: Prix_TTC, dtype: float64

# %% [markdown]
# **Renormer la colonne "discounted_price"**

# %%
# Faisons d'abord une nouvelle copie de notre jeu de données avant de le modifier
df3 = df2.copy()

# %%
# Maintenant on renorme la colonne
df3 = df3.rename(columns={"discounted_price": "prix_remisé"})

# %% [markdown]
# # **Quiz 1 : Quel est le vrai prix sans discount du produit le moins cher en termes de prix TTC parmi les mieux notés ?**

# %%
# Que demande ce quiz ?
# C'est la même question que le problème 1 à l'exception qu'on remplace discounted price par prix TTC
# On cherche le vrai prix dans discount (c'est-à-dire la colonne actual_price) du produit le moins cher (colonne discounted price)
# parmi les mieux notés (colonne rating)

# Pour ce faire il faut :
# 1. Trouver la meilleure note
# 2. Filtrer les produits ayant cette note
# 3. Trouver le prix TTC le plus bas parmi ceux-là
# 4. Garder uniquement les lignes qui ont ce prix
# 5. Afficher le résultat

# %%
# 1. Trouver la meilleure note
meilleur_note = df3['rating'].max()

# 2. Filtrer les produits ayant cette note
high_rating = df3[df3['rating'] == meilleur_note]

# 3. Trouver le prix le plus bas parmi ceux-là
min_price = high_rating['Prix_TTC'].min() # Attention, on avait renommé la colonne, ce n'est plus discounted_prix

# 4. Garder uniquement les lignes qui ont ce prix
result = high_rating[high_rating['Prix_TTC'] == min_price]

# 5. Afficher le résultat
result[['actual_price']]
# Out:
#      actual_price
# 324         999.0

# %% [markdown]
# # **Quiz 2 : Quel est le prix TTC du produit le mieux noté parmi les moins chers en termes de prix remisé ?**

# %%
# 1. Trouver le prix remisé le plus bas globalement
min_price = df3['prix_remisé'].min()

# 2. Filtrer les produits ayant ce prix
cheapest_products = df3[df3['prix_remisé'] == min_price]

# 3. Parmi eux, trouver ceux ayant la meilleure note
max_rating = cheapest_products['rating'].max()

# 4. Sélectionner les produits avec ce rating maximal
result = cheapest_products[cheapest_products['rating'] == max_rating]

# 5. Afficher le prix TTC
result['Prix_TTC']
# Out:
# 975    46.02
# Name: Prix_TTC, dtype: float64

# %% [markdown]
# # **Lien vers le jeu de données utilisée**
#
# https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset
